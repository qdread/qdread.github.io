# %% [markdown]
# # Talks markdown generator for academicpages
#
# Takes a TSV of talks with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `talks.py`. Run either from the `markdown_generator` folder after replacing `talks.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases, rather than Stuart's non-standard TSV format and citation style.

# %%
import pandas as pd
import os

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: title, type, url_slug, venue, date, location, talk_url, description, with a header at the top. Many of these fields can be blank, but the columns must be in the TSV.
#
# - Fields that cannot be blank: `title`, `url_slug`, `date`. All else can be blank. `type` defaults to "Talk"
# - `date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper.
#     - The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/talks/YYYY-MM-DD-[url_slug]`
#     - The combination of `url_slug` and `date` must be unique, as it will be the basis for your filenames
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %%
# !Powershell.exe -Command type talks.tsv -Head 3
# Out:
# title	type	url_slug	venue	date	location	talk_url	description
# Doing more with less: using prior knowledge and creative experimental design to get more results from fewer animals	Invited talk	talk-iacuc2024	"USDA Agricultural Research Service, FY2024 IACUC workshop"	2024-07-18	"Stuttgart, Arkansas"	https://usda-ree-ars.github.io/SEAStats/talks/doing_more_with_less
# Exploring the options for quantifying uncertainty in derivatives of splines	Conference presentation	talk-nccc2024	"NCCC-170: Research Advances in Agricultural Statistics"	2024-06-13	"Mayaguez, Puerto Rico"

# %% [markdown]
# ## Import TSV
#
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
#
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# %%
talks = pd.read_csv("talks.tsv", sep="\t", header=0)
talks
# Out:
#                                                 title  \
# 0   Doing more with less: using prior knowledge an...
# 1   Exploring the options for quantifying uncertai...
# 2   Analyzing ordered categorical phenotypes: chal...
# 3   Troubleshooting common errors and warnings in ...
# 4   Statistical interactions: what are they and wh...
# 5   Everything you ever wanted to know about means...
# 6   A smorgasbord of options for multiomics data a...
# 7        Structural equation modeling in food science
# 8   Power analysis: bureaucratic busywork or criti...
# 9   'Boring' for insights in a 28-year sugarcane i...
# 10  Reducing food waste from farm to fork to benef...
# 11             Food waste: wicked problem or win-win?
# 12  Reducing food waste to benefit environment and...
# 13  Which supply chain stages should we target to ...
# 14  Measuring geodiversity to explain biodiversity...
# 15  Intraspecific variation reflects drivers of ro...
# 16  A globally replicated experiment shows that lo...
# 17                 Food waste impacts on biodiversity
# 18  Challenges in the functional trait approach to...
# 19     Intraspecific variation and community assembly
# 20  Individual variation in organismal traits: pre...
# 21      C3UBE undergraduate biology curriculum reform
# 22      Roots, leaves, and soils facing global change
# 23  Plant traits & interactions altered by warming...
#
#                        type           url_slug  \
# 0              Invited talk     talk-iacuc2024
# 1   Conference presentation      talk-nccc2024
# 2              Invited talk      talk-sibs2024
# 3              Invited talk  talk-honeybee2024
# 4              Invited talk      talk-srrc2024
# 5              Invited talk    talk-dbnrrc2024
# 6              Invited talk      talk-mmru2024
# 7              Invited talk   talk-fsmqhru2023
# 8              Invited talk     talk-iacuc2023
# 9   Conference presentation   talk-agstats2023
# 10             Invited talk      talk-ncsu2022
# 11             Invited talk       talk-gwu2021
# 12             Invited talk      talk-duke2020
# 13  Conference presentation  talk-esaussee2019
# 14  Conference presentation      talk-iale2018
# 15  Conference presentation       talk-esa2017
# 16  Conference presentation       talk-esa2015
# 17             Invited talk       talk-cec2018
# 18             Invited talk      talk-idiv2017
# 19             Invited talk      talk-neon2017
# 20             Invited talk       talk-msu2016
# 21             Invited talk        talk-nd2015
# 22             Invited talk      talk-rmbl2014
# 23             Invited talk      talk-ornl2014
#
#                                                 venue        date  \
# 0   USDA Agricultural Research Service, FY2024 IAC...  2024-07-18
# 1   NCCC-170: Research Advances in Agricultural St...  2024-06-13
# 2           USDA SIBS Phenomics Working Group seminar  2024-03-22
# 3                              USDA ARS Honey Bee Lab  2024-03-07
# 4         USDA ARS Southeast Regional Research Center  2024-03-04
# 5   USDA ARS Dale Bumpers National Rice Research C...  2024-01-10
# 6   USDA Agricultural Research Service & Arkansas ...  2024-01-09
# 7   USDA Agricultural Research Service, Food Scien...  2023-08-02
# 8   USDA Agricultural Research Service, FY2023 IAC...  2023-07-25
# 9   AgStats (Conference on Applied Statistics in A...  2023-05-16
# 10  North Carolina State University, Plant & Micro...  2022-04-05
# 11  George Washington University, guest lecture in...  2021-11-09
# 12  Duke University, University Program in Ecology...  2020-10-08
# 13  Ecological Society of America/U.S. Society for...  2019-08-14
# 14     International Association of Landscape Ecology  2018-04-09
# 15                      Ecological Society of America  2017-08-08
# 16                      Ecological Society of America  2015-08-11
# 17            Commission on Environmental Cooperation  2018-10-24
# 18  German Centre for Integrative Biodiversity Res...  2017-11-15
# 19  National Ecological Observatory Network, weekl...  2017-01-05
# 20  Michigan State University, Hanover Forest Scie...  2016-09-20
# 21  University of Notre Dame, Biology education se...  2015-03-01
# 22  Rocky Mountain Biological Laboratory, weekly s...  2014-06-01
# 23  Oak Ridge National Laboratory, Environmental S...  2014-01-15
#
#                    location  \
# 0       Stuttgart, Arkansas
# 1     Mayaguez, Puerto Rico
# 2   Raleigh, North Carolina
# 3    Baton Rouge, Louisiana
# 4    New Orleans, Louisiana
# 5       Stuttgart, Arkansas
# 6     Little Rock, Arkansas
# 7   Raleigh, North Carolina
# 8           Athens, Georgia
# 9   West Lafayette, Indiana
# 10  Raleigh, North Carolina
# 11           Washington, DC
# 12   Durham, North Carolina
# 13     Louisville, Kentucky
# 14        Chicago, Illinois
# 15         Portland, Oregon
# 16      Baltimore, Maryland
# 17      Arlington, Virginia
# 18         Leipzig, Germany
# 19        Boulder, Colorado
# 20   East Lansing, Michigan
# 21      Notre Dame, Indiana
# 22         Gothic, Colorado
# 23     Oak Ridge, Tennessee
#
#                                              talk_url  \
# 0   https://usda-ree-ars.github.io/SEAStats/talks/...
# 1                                                 NaN
# 2   https://usda-ree-ars.github.io/SEAStats/talks/...
# 3   https://usda-ree-ars.github.io/SEAStats/talks/...
# 4   https://usda-ree-ars.github.io/SEAStats/talks/...
# 5   https://usda-ree-ars.github.io/SEAStats/talks/...
# 6   https://usda-ree-ars.github.io/SEAStats/talks/...
# 7   https://usda-ree-ars.github.io/SEAStats/talks/...
# 8   https://usda-ree-ars.github.io/SEAStats/talks/...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
#
#                                           description
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  at Food Loss and Waste Measurement Experts Gro...
# 18                                                NaN
# 19                       Co-delivered with John Grady
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    if type(text) is str:
        return "".join(html_escape_table.get(c,c) for c in text)
    else:
        return "False"

# %%
# Fix the issues with publication date (excel)
talks = talks.head(1)
str(talks['date'])
# Out:
# '0    2024-07-18\n1    2024-06-13\n2    2024-03-22\n3    2024-03-07\n4    2024-03-04\n5    2024-01-10\n6    2024-01-09\n7    2023-08-02\n8    2023-07-25\nName: date, dtype: object'

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
loc_dict = {}

for row, item in talks.iterrows():
    
    md_filename = str(item.date) + "-" + item.url_slug + ".md"
    html_filename = str(item.date) + "-" + item.url_slug 
    year = item.date[:4]
    
    md = "---\ntitle: \""   + item.title + '"\n'
    md += "collection: talks" + "\n"
    
    if len(str(item.type)) > 3:
        md += 'type: "' + item.type + '"\n'
    else:
        md += 'type: "Talk"\n'
    
    md += "permalink: /talks/" + html_filename + "\n"
    
    if len(str(item.venue)) > 3:
        md += 'venue: "' + item.venue + '"\n'
        
    if len(str(item.location)) > 3:
        md += "date: " + str(item.date) + "\n"
    
    if len(str(item.location)) > 3:
        md += 'location: "' + str(item.location) + '"\n'
           
    md += "---\n"
    
    
    if len(str(item.talk_url)) > 3:
        md += "\n[More information here](" + item.talk_url + ")\n" 
        
    
    if len(str(item.description)) > 3:
        md += "\n" + html_escape(item.description) + "\n"
        
        
    md_filename = os.path.basename(md_filename)
    #print(md)
    
    with open("../_talks/" + md_filename, 'w') as f:
        f.write(md)

# %% [markdown]
# These files are in the talks directory, one directory below where we're working from.

# %%
# %%cmd
# dir ..\_talks\
# Out:
# Microsoft Windows [Version 10.0.22631.3737]
# (c) Microsoft Corporation. All rights reserved.
#
# C:\Users\Quentin.Read\Documents\GitHub\qdread.github.io\markdown_generator>dir ..\_talks\
#  Volume in drive C is OS
#  Volume Serial Number is 262B-7618
#
#  Directory of C:\Users\Quentin.Read\Documents\GitHub\qdread.github.io\_talks
#
# 06/19/2024  06:07 AM    <DIR>          .
# 05/27/2024  09:17 AM    <DIR>          ..
# 04/11/2024  11:41 AM               309 2014-01-15-talk-ornl2014.md
# 04/11/2024  11:41 AM               262 2014-06-01-talk-rmbl2014.md
# 04/11/2024  11:41 AM               262 2015-03-01-talk-nd2015.md
# 04/11/2024  11:41 AM               363 2015-08-11-talk-esa2015.md
# 04/11/2024  11:41 AM               342 2016-09-20-talk-msu2016.md
# 04/11/2024  11:41 AM               299 2017-01-05-talk-neon2017.md
# 04/11/2024  11:41 AM               324 2017-08-08-talk-esa2017.md
# 04/11/2024  11:41 AM               287 2017-11-15-talk-idiv2017.md
# 04/11/2024  11:41 AM               335 2018-04-09-talk-iale2018.md
# 04/11/2024  11:41 AM               300 2018-10-24-talk-cec2018.md
# 04/11/2024  11:41 AM               366 2019-08-14-talk-esaussee2019.md
# 04/11/2024  11:41 AM               328 2020-10-08-talk-duke2020.md
# 04/11/2024  11:41 AM               289 2021-11-09-talk-gwu2021.md
# 04/11/2024  11:41 AM               310 2022-04-05-talk-ncsu2022.md
# 04/11/2024  11:41 AM               331 2023-05-16-talk-agstats2023.md
# 04/11/2024  11:41 AM               312 2023-07-25-talk-iacuc2023.md
# 04/11/2024  11:41 AM               317 2023-08-02-talk-fsmqhru2023.md
# 04/11/2024  11:41 AM               296 2024-01-09-talk-mmru2024.md
# 04/11/2024  11:41 AM               302 2024-01-10-talk-dbnrrc2024.md
# 04/11/2024  11:41 AM               284 2024-03-04-talk-srrc2024.md
# 04/11/2024  11:41 AM               252 2024-03-07-talk-honeybee2024.md
# 06/19/2024  06:07 AM               278 2024-03-22-talk-sibs2024.md
# 06/19/2024  06:07 AM               310 2024-06-13-talk-nccc2024.md
#               23 File(s)          7,058 bytes
#                2 Dir(s)  260,634,001,408 bytes free
#
# C:\Users\Quentin.Read\Documents\GitHub\qdread.github.io\markdown_generator>
