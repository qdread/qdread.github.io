# %% [markdown]
# # Talks markdown generator for academicpages
#
# Takes a TSV of talks with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `talks.py`. Run either from the `markdown_generator` folder after replacing `talks.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases, rather than Stuart's non-standard TSV format and citation style.

# %%
import pandas as pd
import os

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: title, type, url_slug, venue, date, location, talk_url, description, with a header at the top. Many of these fields can be blank, but the columns must be in the TSV.
#
# - Fields that cannot be blank: `title`, `url_slug`, `date`. All else can be blank. `type` defaults to "Talk"
# - `date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper.
#     - The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/talks/YYYY-MM-DD-[url_slug]`
#     - The combination of `url_slug` and `date` must be unique, as it will be the basis for your filenames
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %%
# !Powershell.exe -Command type talks.tsv -Head 3
# Out:
# title	type	url_slug	venue	date	location	talk_url	description
# Everything you ever wanted to know about means comparisons but were afraid to ask	Invited talk	talk-dbnrrc2024	"USDA ARS Dale Bumpers National Rice Research Center"	2024-01-10	"Stuttgart, Arkansas"
# A smorgasbord of options for multiomics data analysis	Invited talk	talk-mmru2024	"USDA Agricultural Research Service & Arkansas Children's Nutrition Center"	2024-01-09	"Little Rock, Arkansas"

# %% [markdown]
# ## Import TSV
#
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
#
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# %%
talks = pd.read_csv("talks.tsv", sep="\t", header=0)
talks
# Out:
#                                                 title  \
# 0   Everything you ever wanted to know about means...
# 1   A smorgasbord of options for multiomics data a...
# 2        Structural equation modeling in food science
# 3   Power analysis: bureaucratic busywork or criti...
# 4   'Boring' for insights in a 28-year sugarcane i...
# 5   Reducing food waste from farm to fork to benef...
# 6              Food waste: wicked problem or win-win?
# 7   Reducing food waste to benefit environment and...
# 8   Which supply chain stages should we target to ...
# 9   Measuring geodiversity to explain biodiversity...
# 10  Intraspecific variation reflects drivers of ro...
# 11  A globally replicated experiment shows that lo...
# 12                 Food waste impacts on biodiversity
# 13  Challenges in the functional trait approach to...
# 14     Intraspecific variation and community assembly
# 15  Individual variation in organismal traits: pre...
# 16      C3UBE undergraduate biology curriculum reform
# 17      Roots, leaves, and soils facing global change
# 18  Plant traits & interactions altered by warming...
#
#                        type           url_slug  \
# 0              Invited talk    talk-dbnrrc2024
# 1              Invited talk      talk-mmru2024
# 2              Invited talk   talk-fsmqhru2023
# 3              Invited talk     talk-iacuc2023
# 4   Conference presentation   talk-agstats2023
# 5              Invited talk      talk-ncsu2022
# 6              Invited talk       talk-gwu2021
# 7              Invited talk      talk-duke2020
# 8   Conference presentation  talk-esaussee2019
# 9   Conference presentation      talk-iale2018
# 10  Conference presentation       talk-esa2017
# 11  Conference presentation       talk-esa2015
# 12             Invited talk       talk-cec2018
# 13             Invited talk      talk-idiv2017
# 14             Invited talk      talk-neon2017
# 15             Invited talk       talk-msu2016
# 16             Invited talk        talk-nd2015
# 17             Invited talk      talk-rmbl2014
# 18             Invited talk      talk-ornl2014
#
#                                                 venue        date  \
# 0   USDA ARS Dale Bumpers National Rice Research C...  2024-01-10
# 1   USDA Agricultural Research Service & Arkansas ...  2024-01-09
# 2   USDA Agricultural Research Service, Food Scien...  2023-08-02
# 3   USDA Agricultural Research Service, FY2023 IAC...  2023-07-25
# 4   AgStats (Conference on Applied Statistics in A...  2023-05-16
# 5   North Carolina State University, Plant & Micro...  2022-04-05
# 6   George Washington University, guest lecture in...  2021-11-09
# 7   Duke University, University Program in Ecology...  2020-10-08
# 8   Ecological Society of America/U.S. Society for...  2019-08-14
# 9      International Association of Landscape Ecology  2018-04-09
# 10                      Ecological Society of America  2017-08-08
# 11                      Ecological Society of America  2015-08-11
# 12            Commission on Environmental Cooperation  2018-10-24
# 13  German Centre for Integrative Biodiversity Res...  2017-11-15
# 14  National Ecological Observatory Network, weekl...  2017-01-05
# 15  Michigan State University, Hanover Forest Scie...  2016-09-20
# 16  University of Notre Dame, Biology education se...  2015-03-01
# 17  Rocky Mountain Biological Laboratory, weekly s...  2014-06-01
# 18  Oak Ridge National Laboratory, Environmental S...  2014-01-15
#
#                    location  talk_url  \
# 0       Stuttgart, Arkansas       NaN
# 1     Little Rock, Arkansas       NaN
# 2   Raleigh, North Carolina       NaN
# 3           Athens, Georgia       NaN
# 4   West Lafayette, Indiana       NaN
# 5   Raleigh, North Carolina       NaN
# 6            Washington, DC       NaN
# 7    Durham, North Carolina       NaN
# 8      Louisville, Kentucky       NaN
# 9         Chicago, Illinois       NaN
# 10         Portland, Oregon       NaN
# 11      Baltimore, Maryland       NaN
# 12      Arlington, Virginia       NaN
# 13         Leipzig, Germany       NaN
# 14        Boulder, Colorado       NaN
# 15   East Lansing, Michigan       NaN
# 16      Notre Dame, Indiana       NaN
# 17         Gothic, Colorado       NaN
# 18     Oak Ridge, Tennessee       NaN
#
#                                           description
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  at Food Loss and Waste Measurement Experts Gro...
# 13                                                NaN
# 14                       Co-delivered with John Grady
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    if type(text) is str:
        return "".join(html_escape_table.get(c,c) for c in text)
    else:
        return "False"

# %%
# Fix the issues with publication date (excel)
talks = talks.head(2)
str(talks['date'])
# Out:
# '0    2024-01-10\n1    2024-01-09\nName: date, dtype: object'

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
loc_dict = {}

for row, item in talks.iterrows():
    
    md_filename = str(item.date) + "-" + item.url_slug + ".md"
    html_filename = str(item.date) + "-" + item.url_slug 
    year = item.date[:4]
    
    md = "---\ntitle: \""   + item.title + '"\n'
    md += "collection: talks" + "\n"
    
    if len(str(item.type)) > 3:
        md += 'type: "' + item.type + '"\n'
    else:
        md += 'type: "Talk"\n'
    
    md += "permalink: /talks/" + html_filename + "\n"
    
    if len(str(item.venue)) > 3:
        md += 'venue: "' + item.venue + '"\n'
        
    if len(str(item.location)) > 3:
        md += "date: " + str(item.date) + "\n"
    
    if len(str(item.location)) > 3:
        md += 'location: "' + str(item.location) + '"\n'
           
    md += "---\n"
    
    
    if len(str(item.talk_url)) > 3:
        md += "\n[More information here](" + item.talk_url + ")\n" 
        
    
    if len(str(item.description)) > 3:
        md += "\n" + html_escape(item.description) + "\n"
        
        
    md_filename = os.path.basename(md_filename)
    #print(md)
    
    with open("../_talks/" + md_filename, 'w') as f:
        f.write(md)

# %% [markdown]
# These files are in the talks directory, one directory below where we're working from.

# %%
# %%cmd
# dir ..\_talks\
# Out:
# Microsoft Windows [Version 10.0.19045.3803]
# (c) Microsoft Corporation. All rights reserved.
#
# C:\Users\qdread\Documents\GitHub\qdread.github.io\markdown_generator>dir ..\_talks\
#  Volume in drive C has no label.
#  Volume Serial Number is 08D0-A2BB
#
#  Directory of C:\Users\qdread\Documents\GitHub\qdread.github.io\_talks
#
# 01/16/2024  09:32 AM    <DIR>          .
# 01/16/2024  09:32 AM    <DIR>          ..
# 07/31/2023  10:25 AM               309 2014-01-15-talk-ornl2014.md
# 07/31/2023  10:25 AM               262 2014-06-01-talk-rmbl2014.md
# 07/31/2023  10:25 AM               262 2015-03-01-talk-nd2015.md
# 07/31/2023  10:25 AM               363 2015-08-11-talk-esa2015.md
# 07/31/2023  10:25 AM               342 2016-09-20-talk-msu2016.md
# 07/31/2023  10:25 AM               299 2017-01-05-talk-neon2017.md
# 07/31/2023  10:25 AM               324 2017-08-08-talk-esa2017.md
# 07/31/2023  10:25 AM               287 2017-11-15-talk-idiv2017.md
# 07/31/2023  10:25 AM               335 2018-04-09-talk-iale2018.md
# 07/31/2023  10:25 AM               300 2018-10-24-talk-cec2018.md
# 07/31/2023  10:25 AM               366 2019-08-14-talk-esaussee2019.md
# 07/31/2023  10:25 AM               328 2020-10-08-talk-duke2020.md
# 07/31/2023  10:25 AM               289 2021-11-09-talk-gwu2021.md
# 07/31/2023  10:25 AM               310 2022-04-05-talk-ncsu2022.md
# 07/31/2023  10:25 AM               331 2023-05-16-talk-agstats2023.md
# 07/31/2023  10:25 AM               312 2023-07-25-talk-iacuc2023.md
# 07/31/2023  10:25 AM               317 2023-08-02-talk-fsmqhru2023.md
# 01/16/2024  09:32 AM               296 2024-01-09-talk-mmru2024.md
# 01/16/2024  09:32 AM               302 2024-01-10-talk-dbnrrc2024.md
#               19 File(s)          5,934 bytes
#                2 Dir(s)  136,828,977,152 bytes free
#
# C:\Users\qdread\Documents\GitHub\qdread.github.io\markdown_generator>
